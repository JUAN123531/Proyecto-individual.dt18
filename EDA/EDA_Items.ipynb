# %% [markdown]
# Items EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt # Importamos matplotlib.pyplot y seaborn para realizar graficos
import seaborn as sns

# %%
df_items = pd.read_parquet(r'../Data/clean_games_items.parquet.gzip') # Leemos el archivo
df_items.head()
# Out:
#              user_id  items_count           steam_id
# 0  76561197970982479          277  76561197970982479  \
# 0  76561197970982479          277  76561197970982479
# 0  76561197970982479          277  76561197970982479
# 0  76561197970982479          277  76561197970982479
# 0  76561197970982479          277  76561197970982479
#
#                                             user_url item_id
# 0  http://steamcommunity.com/profiles/76561197970...      10  \
# 0  http://steamcommunity.com/profiles/76561197970...      20
# 0  http://steamcommunity.com/profiles/76561197970...      30
# 0  http://steamcommunity.com/profiles/76561197970...      40
# 0  http://steamcommunity.com/profiles/76561197970...      50
#
#                    item_name  playtime_forever  genre
# 0             counter-strike                 6      6
# 0      team fortress classic                 0      0
# 0              day of defeat                 7      7
# 0         deathmatch classic                 0      0
# ...

# %%
# Se calcula la cantidad de registros
print(f'La cantidad de registros que hay son: {df_items.shape[0]}')
# Out:
# La cantidad de registros que hay son: 5153209

# %%
df_items.describe(include='all')
# Out:
#         user_id   items_count           steam_id
# count   5153209  5.153209e+06            5153209  \
# unique    70912           NaN              70912
# top     phrostb           NaN  76561198102767019
# freq       7762           NaN               7762
# mean        NaN  3.147229e+02                NaN
# std         NaN  6.933596e+02                NaN
# min         NaN  1.000000e+00                NaN
# 25%         NaN  7.200000e+01                NaN
# 50%         NaN  1.380000e+02                NaN
# 75%         NaN  2.760000e+02                NaN
# max         NaN  7.762000e+03                NaN
#
#                                     user_url  item_id    item_name
# count                                5153209  5153209      5153209  \
# unique                                 70912    10978        10944
# top     http://steamcommunity.com/id/phrostb   205790  dota 2 test
# freq                                    7762    49571        49571
# ...
